# %% [markdown]
# <a href="https://colab.research.google.com/github/sheezariaz2315/sheezariaz2315-urdu-ocr-codesaviours-si26-sheeza/blob/main/SI26_Week1_sheeza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Urdu OCR Project
#
# ## Week 1
#
# ### Student Name
# Sheeza
#
# ### Project
# Urdu OCR (Optical Character Recognition)
#
# ---
#
# # Research Task

# %% [markdown]
# ## Question 1: What is OCR (Optical Character Recognition)?
#
# OCR (Optical Character Recognition) is a technology that enables computers to recognize text from images, scanned documents, or photographs and convert it into editable digital text. It helps automate data entry and reduces the need for manual typing. OCR is widely used in document digitization, banking, education, and business applications.
#
# ## Question 2: Why is Urdu OCR harder than English OCR?
#
# Urdu OCR is more difficult than English OCR because Urdu is written from right to left and its letters change shape depending on their position in a word. Many Urdu characters look very similar, which makes it challenging for computers to recognize them correctly. Different fonts, handwriting styles, and connected letters also increase the complexity of Urdu OCR.
#
# ## Question 3: What are two real-world situations where Urdu OCR would be useful?
#
# Urdu OCR can be used to digitize old Urdu books, newspapers, and historical documents so they can be searched and preserved digitally. It is also useful for government offices, schools, and libraries to convert printed records into digital databases. Another application is extracting text from Urdu signboards, forms, and invoices for automation and record keeping.

# %%
import os

folders = [
    "data/raw/newspaper",
    "data/raw/books",
    "data/raw/signboards",
    "data/raw/synthetic",
    "data/raw/other"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created: {folder}")

print("Folder structure ready!")
# Out:
# Created: data/raw/newspaper
# Created: data/raw/books
# Created: data/raw/signboards
# Created: data/raw/synthetic
# Created: data/raw/other
# Folder structure ready!

# %%
# !pip install Pillow arabic-reshaper python-bidi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 9.8 MB/s eta 0:00:00
# ...

# %%
# !wget -O NotoNastaliqUrdu-Regular.ttf https://github.com/googlefonts/noto-fonts/raw/main/unhinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf
# Out:
# --2026-07-26 13:54:41--  https://github.com/googlefonts/noto-fonts/raw/main/unhinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/notofonts/noto-fonts/raw/main/unhinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf [following]
# --2026-07-26 13:54:41--  https://github.com/notofonts/noto-fonts/raw/main/unhinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response...

# %%
from PIL import Image, ImageDraw, ImageFont, features
import os
import glob

# Check karo Raqm support hai ya nahi
print("Raqm support:", features.check('raqm'))

# Use the downloaded NotoNastaliqUrdu-Regular.ttf font directly
font_path = '/content/NotoNastaliqUrdu-Regular.ttf'
print("Using font:", font_path)

urdu_texts = [
    "پاکستان زندہ باد",
    "آج کا موسم خوشگوار ہے",
    "تعلیم ہر انسان کا حق ہے",
    "کراچی پاکستان کا سب سے بڑا شہر ہے",
    "محنت کامیابی کی کنجی ہے",
    "علم روشنی ہے",
    "وقت کی قدر کرو",
    "صحت ہزار نعمت ہے",
    "میں پاکستانی ہوں مجھے فخر ہے",
    "ماں کی دعا جنت کی کنجی ہے",
    "کتاب انسان کی بہترین دوست ہے",
    "پانی زندگی ہے",
    "سچ بولنا اچھی عادت ہے",
    "لاہور تاریخی شہر ہے",
    "بارش کا موسم خوبصورت ہے",
    "دوستی ایک انمول رشتہ ہے",
    "محنت کبھی رائیگاں نہیں جاتی",
    "امن سب کے لیے ضروری ہے",
    "استاد قوم کا معمار ہے",
    "خوشی بانٹنے سے بڑھتی ہے"
]

os.makedirs('data/raw/synthetic', exist_ok=True)
font = ImageFont.truetype(font_path, 28)

for i, text in enumerate(urdu_texts):
    img = Image.new('RGB', (400, 80), color='white')
    draw = ImageDraw.Draw(img)
    # direction='rtl' aur language='ur' Raqm ko batata hai ye Urdu hai
    draw.text((390, 25), text, fill='black', font=font,
               direction='rtl', language='ur', anchor='ra')
    img.save(f'data/raw/synthetic/urdu_{i+1}.png')
    print(f'Generated: urdu_{i+1}.png -- {text}')

print('Done! Check data/synthetic/ folder')
# Out:
# Raqm support: True
# Using font: /content/NotoNastaliqUrdu-Regular.ttf
# Generated: urdu_1.png -- پاکستان زندہ باد
# Generated: urdu_2.png -- آج کا موسم خوشگوار ہے
# Generated: urdu_3.png -- تعلیم ہر انسان کا حق ہے
# Generated: urdu_4.png -- کراچی پاکستان کا سب سے بڑا شہر ہے
# Generated: urdu_5.png -- محنت کامیابی کی کنجی ہے
# Generated: urdu_6.png -- علم روشنی ہے
# Generated: urdu_7.png -- وقت کی قدر کرو
# Generated: urdu_8.png -- صحت ہزار نعمت ہے
# Generated: urdu_9.png -- میں پاکستانی ہوں مجھے فخر ہے
# Generated: urdu_10.png -- ماں کی دعا جنت کی کنجی ہے
# Generated: urdu_11.png -- کتاب انسان کی بہترین دوست ہے
# Generated: urdu_12.png -- پانی زندگی ہے
# Generated: urdu_13.png -- سچ بولنا اچھی عادت ہے
# Generated: urdu_14.png -- لاہور تاریخی شہر ہے
# Generated: urdu_15.png -- بارش کا موسم خوبصورت ہے
# Generated: urdu_16.png -- دوستی ایک انمول رشتہ ہے
# Generated: urdu_17.png -- محنت کبھی رائیگاں نہیں جاتی
# Generated: urdu_18.png -- امن سب کے لیے ضروری ہے
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

print(os.listdir("/content/drive/MyDrive"))
# Out:
# ['Colab Notebooks', 'IMG_7230.JPG', 'IMG_7217.JPG', 'IMG_7228.JPG', 'IMG_7127.JPG', 'IMG_7182.JPG', 'IMG_7241.JPG', 'IMG_7156.JPG', 'IMG_6986.JPG', 'IMG_7138.JPG', 'IMG_7260.JPG', 'IMG_7180.JPG', 'IMG_7165.JPG', 'IMG_7237.JPG', 'IMG_7268.JPG', 'IMG_7287.JPG', 'IMG_7284.JPG', 'IMG_7199.JPG', 'IMG_6999.JPG', 'IMG_7225.JPG', 'IMG_7125.JPG', 'IMG_7272.JPG', 'IMG_7154.JPG', 'IMG_7019.JPG', 'IMG_7181.JPG', 'IMG_7025.JPG', 'IMG_7051.JPG', 'IMG_7072.JPG', 'IMG_7065.JPG', 'IMG_7240.JPG', 'IMG_7257.JPG', 'IMG_7161.JPG', 'IMG_7136.JPG', 'IMG_7152.JPG', 'IMG_7150.JPG', 'IMG_7310.JPG', 'IMG_7109.JPG', 'IMG_7286.JPG', 'IMG_7079.JPG', 'IMG_7233.JPG', 'IMG_7073.JPG', 'IMG_7048.JPG', 'IMG_7098.JPG', 'IMG_7106.JPG', 'IMG_7092.JPG', 'IMG_7043.JPG', 'IMG_7059.JPG', 'IMG_7036.JPG', 'IMG_7023.JPG', 'IMG_7039.JPG', 'IMG_7004.JPG', 'IMG_7265.JPG', 'IMG_7187.JPG', 'IMG_7208.JPG', 'IMG_7191.JPG', 'IMG_7084.PNG', 'IMG_7140.JPG', 'IMG_7196.JPG', 'IMG_7279.PNG', 'IMG_7192.JPG', 'IMG_7223.JPG', 'IMG_7267.JPG', 'I
# ...

# %%
import shutil
import os

source = "data/raw/synthetic"
destination = "/content/drive/MyDrive/Urdu-OCR/synthetic"

os.makedirs(destination, exist_ok=True)

for file in os.listdir(source):
    shutil.copy(os.path.join(source, file), destination)

print("Done!")
# Out:
# Done!

# %%
import shutil
import os

source = "/content/data/raw/synthetic"
destination = "/content/drive/MyDrive/Urdu-OCR/synthetic"

os.makedirs(destination, exist_ok=True)

for file_name in os.listdir(source):
    source_path = os.path.join(source, file_name)
    if os.path.isfile(source_path):
        shutil.copy(
            source_path,
            os.path.join(destination, file_name)
        )

print("✅ All synthetic images copied to Google Drive!")
# Out:
# ✅ All synthetic images copied to Google Drive!

# %%
import os
import shutil

drive_base = "/content/drive/MyDrive/Urdu-OCR"
colab_base = "/content/data/raw"

folders = [
    "newspaper",
    "books",
    "signboards",
    "other",
    "synthetic"
]

# Copy image folders
for folder in folders:
    src = os.path.join(drive_base, folder)
    dst = os.path.join(colab_base, folder)

    os.makedirs(dst, exist_ok=True)

    for file in os.listdir(src):
        shutil.copy2(
            os.path.join(src, file),
            os.path.join(dst, file)
        )

# ==========================
# Copy labels.csv
# ==========================

src_csv = os.path.join(drive_base, "labels.csv")
dst_csv = "/content/data/labels.csv"

os.makedirs("/content/data", exist_ok=True)

if os.path.exists(src_csv):
    shutil.copy2(src_csv, dst_csv)
    print("✅ labels.csv copied successfully!")
else:
    print("❌ labels.csv not found in Google Drive.")

print("✅ All images copied successfully!")
# Out:
# ✅ labels.csv copied successfully!
# ✅ All images copied successfully!

# %%
import csv

labels = [

# ===========================
# NEWSPAPER
# ===========================

{"image":"data/raw/newspaper/news001.png","text":"روزنامہ جنگ راولپنڈی۔ کسی جہاز کو نقصان پہنچایا تو وادی کی منجمد اثاثوں سے کی گئی، ایران کو ہتھیار بھیجے تو بہت مہنگا پڑے گا: ٹرمپ۔ دہشت گردی کے پیچھے بھارت کا ہاتھ، وسائل بھی مہیا کر رہا ہے، افغان سرزمین پاکستان کے خلاف استعمال کر رہے ہیں: وزیر اعظم۔ خودکش حملہ: 15 ملک کے شاندار شہید، 12 دہشت گرد ہلاک۔ ٹینک میں دھماکہ خیز مواد سے بھری گاڑی چیک پوسٹ سے ٹکرا دی، فورسز کی بروقت جوابی کارروائی۔"},

{"image":"data/raw/newspaper/news002.png","text":"ایران میں مہنگائی کے خلاف احتجاج شدت اختیار کر گیا، انٹرنیٹ سروس بند، پروازیں منسوخ۔ مظاہروں کے دوران 34 مظاہرین اور 4 سیکیورٹی اہلکار جان بحق، دو ہزار سے زائد افراد گرفتار۔ افغان طالبان کی واپسی کے بعد پاکستان سب سے زیادہ دہشت گردی سے متاثر ملک قرار۔"},

{"image":"data/raw/newspaper/news003.png","text":"ایران میں بے امنی، پاکستانی شہریوں کو غیر ضروری سفر سے گریز کی ہدایت۔ دفتر خارجہ نے ایران میں مقیم پاکستانیوں کو احتیاط برتنے کی ہدایت کی۔ امریکا بھارت تجارتی معاہدہ ملتوی ہونے کی وجہ مودی کا ٹرمپ کو کال نہ کرنا تھا۔"},

{"image":"data/raw/newspaper/news004.png","text":"بنگلہ دیش اور پاکستان کے درمیان 14 سال بعد براہ راست پروازیں بحال، شیڈول جاری۔ ایران میں احتجاج کا 12 واں روز، مظاہرے کے دوران پولیس افسر جان بحق۔"},

{"image":"data/raw/newspaper/news005.png","text":"پاکستان اور سعودی عرب کے درمیان دفاعی تعاون مزید مضبوط بنانے پر اتفاق۔ ایئر چیف مارشل ظہیر احمد بابر سدھو کی سعودی عسکری قیادت سے ملاقات۔ امریکا میں امیگریشن افسر کی فائرنگ سے خاتون ہلاک، بڑے پیمانے پر احتجاج۔"},

{"image":"data/raw/newspaper/news006.png","text":"ترجمان کے الیکٹرک کا کہنا ہے کہ بارش کے دوران شہر میں کے الیکٹرک کا ترسیلی نظام مجموعی طور پر مستحکم رہا۔ تقریباً 90 فیصد فیڈرز سے بجلی کی فراہمی بلا تعطل جاری رہی۔"},

{"image":"data/raw/newspaper/news007.png","text":"ٹرمپ نے پاکستان، چین، بھارت سمیت 60 ممالک پر نئے ٹیرف نافذ کر دیے۔ آزاد کشمیر اور بھارتی مقبوضہ کشمیر کی صورتحال میں واضح فرق ہے۔ ایران حملہ اور نئے ٹیرف امریکی معیشت کیلئے خطرہ۔"},

{"image":"data/raw/newspaper/news008.png","text":"اسلام آباد ہائی کورٹ نے متنازع ٹوئٹس کیس میں ایمان مزاری اور ہادی چٹھہ کی سزا معطلی کی درخواستوں کو قابل سماعت قرار دے دیا۔"},

{"image":"data/raw/newspaper/news009.png","text":"سندھ کے مختلف اضلاع میں آج سے 27 جولائی تک وقفے وقفے سے بارش کا امکان ہے۔ محکمہ موسمیات کے مطابق کراچی میں آئندہ تین روز بارش اور بوندا باندی متوقع ہے۔"},

{"image":"data/raw/newspaper/news010.png","text":"امیر جماعت اسلامی کراچی منعم ظفر خان کا کہنا ہے کہ گزشتہ روز بارش کے پہلے قطرے کے ساتھ ہی 200 فیڈرز ٹرپ کر گئے۔ سندھ حکومت اور کے الیکٹرک پر شدید تنقید۔"},

{"image":"data/raw/newspaper/news011.png","text":"ٹک ٹاک کا پاکستان میں چھوٹے کاروبار کیلئے سیلف سروس ایڈورٹائزنگ پلیٹ فارم متعارف۔ پاکستانی یوٹیوب مواد کے مجموعی واچ ٹائم میں 60 فیصد بیرون ملک ناظرین کا حصہ۔"},

{"image":"data/raw/newspaper/news012.png","text":"ٹوائلٹ میں تصاویر کھینچنے کیلئے بنائے گئے کیمرے کے ڈیٹا تک دوسروں کو رسائی کا انکشاف۔ یوٹیوب کا نیا ری کیپ فیچر، صارفین اب سال بھر دیکھی گئی ویڈیوز کا خلاصہ دیکھ سکیں گے۔"},

{"image":"data/raw/newspaper/news013.png","text":"پاکستانی مسافروں کیلئے بڑی خبر، یو اے ای پہنچنے پر طویل امیگریشن کارروائی سے چھٹکارا۔ بھارت کا آٹھ ماہ میں دوسرا خلائی مشن ناکام۔"},

{"image":"data/raw/newspaper/news014.png","text":"حملے کی صورت میں ایران کی اسرائیل اور امریکی اڈوں کو نشانہ بنانے کی دھمکی۔ ایرانی عوام آزادی چاہتے ہیں، امریکا ان کی مدد کیلئے تیار ہے، ڈونلڈ ٹرمپ۔"},

{"image":"data/raw/newspaper/news015.png","text":"ترکیہ پاکستان اور سعودی عرب کے باہمی دفاعی معاہدے میں شمولیت کا خواہاں، نیا سیکورٹی اتحاد متوقع۔ بنگلہ دیش نے بھارت میں اپنے سفارتی مشنز کے ویزا سیکشن بند کر دیے۔"},

{"image":"data/raw/newspaper/news016.png","text":"بنگلہ دیش نے آئی پی ایل کی نشریات پر پابندی لگا دی۔ غلامی کے دن ختم، بنگلہ دیش کا اپنے ورلڈ کپ میچز بھارت سے منتقل کروانے کا عندیہ۔"},

{"image":"data/raw/newspaper/news017.png","text":"دو روز میں ٹیسٹ میچ ختم، آئی سی سی نے میلبورن کرکٹ گراؤنڈ کی پچ ناقص قرار دے دی۔ تمیز کے دائرے میں رہنا، سرفراز احمد کا جملہ ایشیا کپ کی فتح سے زیادہ وائرل۔"},

{"image":"data/raw/newspaper/news018.png","text":"بھارتی کھلاڑیوں کے رویے مناسب نہیں تھے، سرفراز احمد۔ پاکستان نے فیورٹ بھارت کو باآسانی چت کرکے انڈر 19 ایشیا کپ جیت لیا۔"},

{"image":"data/raw/newspaper/news019.png","text":"میسی کی آمد پر کولکتہ اسٹیڈیم میں شدید بدنظمی، توڑ پھوڑ، واقعے کی تحقیقات کیلئے کمیٹی تشکیل۔ جنت نظیر وادی آزاد کشمیر میں پی ایس ایل کا میدان سجنے کو تیار۔"},

{"image":"data/raw/newspaper/news020.png","text":"حکومت کا گیس مہنگی کرنے کے بجائے پیٹرولیم لیوی مزید بڑھانے کا منصوبہ۔ اسٹاک ایکسچینج میں نئی تاریخ رقم، ایک لاکھ 79 ہزار کی بلند سطح بھی عبور۔"},
# ===========================
# BOOKS
# ===========================

{"image":"data/raw/books/books001.png","text":"نہ لا تعلق رہو، نہ توقعات پال لو"},

{"image":"data/raw/books/books002.png","text":"عبداللہ"},

{"image":"data/raw/books/books003.png","text":"اردو ناولوں کا مجموعہ"},

{"image":"data/raw/books/books004.png","text":"الحاصل"},

{"image":"data/raw/books/books005.png","text":"تم مجھے یاد آؤ گے"},

{"image":"data/raw/books/books006.png","text":"محبت انسان کو بدل دیتی ہے"},

{"image":"data/raw/books/books007.png","text":"حاصل"},

{"image":"data/raw/books/books008.png","text":"راز، زندگی، سکون"},

{"image":"data/raw/books/books009.png","text":"واہ انسان، یہ تیرا امتحان ہے"},

{"image":"data/raw/books/books010.png","text":"عبداللہ"},

{"image":"data/raw/books/books011.png","text":"رمان دل"},

{"image":"data/raw/books/books012.png","text":"چہرہ"},

{"image":"data/raw/books/books013.png","text":"موجودہ"},

{"image":"data/raw/books/books014.png","text":"راز پنہاں"},

{"image":"data/raw/books/books015.png","text":"چاند کی تلاش انسان نے نہیں روکی"},

{"image":"data/raw/books/books016.png","text":"زندگی کو دوسروں سے مت ناپو"},

{"image":"data/raw/books/books017.png","text":"دنیا کو کوئی روزہ دار مکمل سمجھ کر مت اپناؤ"},

{"image":"data/raw/books/books018.png","text":"تمہارا انتظار ہمیشہ رہے گا"},

{"image":"data/raw/books/books019.png","text":"تکبر انسان کو اندھا کر دیتا ہے"},

{"image":"data/raw/books/books020.png","text":"کچھ لوگ دل میں ہمیشہ رہ جاتے ہیں"},                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            # ===========================
# SIGNBOARDS
# ===========================

{"image":"data/raw/signboards/signboard001.png","text":"قصر آئینہ"},

{"image":"data/raw/signboards/signboard002.png","text":"راولپنڈی RAWALPINDI"},

{"image":"data/raw/signboards/signboard003.png","text":"KOSHISH کوشش"},

{"image":"data/raw/signboards/signboard004.png","text":"Caution CNG PUMPS، No Smoking، سگریٹ نوشی منع ہے، No Naked Light، کھلی آگ جلانا منع ہے، No Mobile Phones، موبائل فون منع ہے، Switch Off Engine، انجن بند کریں"},

{"image":"data/raw/signboards/signboard005.png","text":"اسلام آباد، لاہور، کراچی، پشاور، کوئٹہ، ملتان"},

{"image":"data/raw/signboards/signboard006.png","text":"پارک میں جانا منع ہے"},

{"image":"data/raw/signboards/signboard007.png","text":"اس جگہ پیشاب کرنا منع ہے"},

{"image":"data/raw/signboards/signboard008.png","text":"استقبالیہ"},

{"image":"data/raw/signboards/signboard009.png","text":"ٹریفک سائنز کی تیاری"},

{"image":"data/raw/signboards/signboard010.png","text":"وقف برائے نماز"},

{"image":"data/raw/signboards/signboard011.png","text":"ایڈوکیٹ"},

{"image":"data/raw/signboards/signboard012.png","text":"چترال، دیر، Chitral، Dir"},

{"image":"data/raw/signboards/signboard013.png","text":"فلاویون"},

{"image":"data/raw/signboards/signboard014.png","text":"پھول توڑنا، پودوں کو نقصان پہنچانا اور پارک کو گندا کرنا منع ہے"},

{"image":"data/raw/signboards/signboard015.png","text":"المطاف - الصحن، ALMataf - Mataf Square"},

{"image":"data/raw/signboards/signboard016.png","text":"باب الصفا، زمزم پانی پینے کیلئے، مخرج الی المطاف، وضوخانہ - نساء"},

{"image":"data/raw/signboards/signboard017.png","text":"وارڈروب"},

{"image":"data/raw/signboards/signboard018.png","text":"خبردار، پھسلنے کا خطرہ"},

{"image":"data/raw/signboards/signboard019.png","text":"نرسری، ایل کے جی، یو کے جی، اول مکتب، دوم مکتب، سوم مکتب، چہارم مکتب، پنجم مکتب، CLASS I، CLASS II، CLASS III، CLASS IV، CLASS V"},

{"image":"data/raw/signboards/signboard020.png","text":"سرینگر ہائی وے، Srinagar Highway، لیہ، Leh، سرینگر، Srinagar، 733 Km، 300 Km"},
 # ===========================
# OTHER
# ===========================

{"image":"data/raw/other/other001.png","text":"اسکے ساتھ ملحقہ علاقے کے عوام نے بجلی و گیس"},

{"image":"data/raw/other/other002.png","text":"کی لوڈ شیڈنگ کے خلاف مظاہرہ کیا۔ پولیس تشدد سے ایک نوجوان"},

{"image":"data/raw/other/other003.png","text":"منشور علی جاں بحق اور 2 خواتین سمیت 14 افراد زخمی ہو گئے۔"},

{"image":"data/raw/other/other004.png","text":"علاقے میں کرفیو نافذ کر دیا گیا ہے۔ مکینوں نے الزام"},

{"image":"data/raw/other/other005.png","text":"لگایا کہ پولیس کی فائرنگ سے شہری ہلاک ہوا جبکہ"},

{"image":"data/raw/other/other006.png","text":"پولیس کا کہنا ہے کہ مظاہرین میں کسی نے نہم"},

{"image":"data/raw/other/other007.png","text":"پر براہ راست فائرنگ کی اور فائرنگ کے تبادلے کے"},

{"image":"data/raw/other/other008.png","text":"نتیجے میں ایک شہری ہلاک ہو گیا۔ تفصیلات کے مطابق بتول"},

{"image":"data/raw/other/other009.png","text":"میں اقوام منزل اور اسکے ساتھ ملحقہ علاقے کے عوام"},

{"image":"data/raw/other/other010.png","text":"نے بجلی و گیس کی لوڈ شیڈنگ کے خلاف مظاہرہ کیا۔ مظاہرین نے"},

{"image":"data/raw/other/other011.png","text":"مظاہرے کے دوران بینوں، ٹائروں روڈ بلاک کردی اور سٹرک"},

{"image":"data/raw/other/other012.png","text":"خالی کرنے سے انکار کردیا، مظاہرین کو روڈ سے ہٹانے"},

{"image":"data/raw/other/other013.png","text":"کیلئے پولیس نے مظاہرین پر لاٹھی چارج اور فائرنگ کی"},

{"image":"data/raw/other/other014.png","text":"جس سے ایک نوجوان منشور علی جاں بحق اور 2"},

{"image":"data/raw/other/other015.png","text":"خواتین سمیت 14 افراد زخمی ہوئے۔ زخمیوں کو قریبی ہسپتال"},

{"image":"data/raw/other/other016.png","text":"منتقل کر دیا گیا۔ بنوں اور ڈیرہ اسماعیل خان ضلع کو"},

{"image":"data/raw/other/other017.png","text":"ملانے والی مرکزی شاہراہ پر کرفیو نافذ کر دیا گیا ہے۔ بنوں"},

{"image":"data/raw/other/other018.png","text":"میں تشدد اس وقت شروع ہوا جب 500 کے لگ بھگ"},

{"image":"data/raw/other/other019.png","text":"مظاہرین نے مصروف شاہراہ بلاک کر دی اور خالی کرنے سے"},

{"image":"data/raw/other/other020.png","text":"انکار کر دیا۔ مظاہرین نے شاہراہ کو 3 گھنٹے تک بلاک رکھا۔ پولیس کا"},
 # ===========================
# SYNTHETIC
# ===========================

{"image":"data/raw/synthetic/synthetic001.png","text":"پاکستان زندہ باد"},

{"image":"data/raw/synthetic/synthetic002.png","text":"آج کا موسم خوشگوار ہے"},

{"image":"data/raw/synthetic/synthetic003.png","text":"تعلیم ہر انسان کا حق ہے"},

{"image":"data/raw/synthetic/synthetic004.png","text":"کراچی پاکستان کا سب سے بڑا شہر ہے"},

{"image":"data/raw/synthetic/synthetic005.png","text":"محنت کامیابی کی کنجی ہے"},

{"image":"data/raw/synthetic/synthetic006.png","text":"علم روشنی ہے"},

{"image":"data/raw/synthetic/synthetic007.png","text":"وقت کی قدر کرو"},

{"image":"data/raw/synthetic/synthetic008.png","text":"صحت ہزار نعمت ہے"},

{"image":"data/raw/synthetic/synthetic009.png","text":"میں پاکستانی ہوں مجھے فخر ہے"},

{"image":"data/raw/synthetic/synthetic010.png","text":"ماں کی دعا جنت کی کنجی ہے"},

{"image":"data/raw/synthetic/synthetic011.png","text":"کتاب انسان کی بہترین دوست ہے"},

{"image":"data/raw/synthetic/synthetic012.png","text":"پانی زندگی ہے"},

{"image":"data/raw/synthetic/synthetic013.png","text":"سچ بولنا اچھی عادت ہے"},

{"image":"data/raw/synthetic/synthetic014.png","text":"لاہور تاریخی شہر ہے"},

{"image":"data/raw/synthetic/synthetic015.png","text":"بارش کا موسم خوبصورت ہے"},

{"image":"data/raw/synthetic/synthetic016.png","text":"دوستی ایک انمول رشتہ ہے"},

{"image":"data/raw/synthetic/synthetic017.png","text":"محنت کبھی رائیگاں نہیں جاتی"},

{"image":"data/raw/synthetic/synthetic018.png","text":"امن سب کے لیے ضروری ہے"},

{"image":"data/raw/synthetic/synthetic019.png","text":"استاد قوم کا معمار ہے"},

{"image":"data/raw/synthetic/synthetic020.png","text":"خوشی بانٹنے سے بڑھتی ہے"}

]

# %%
import os
import csv

# Local folder
os.makedirs("data", exist_ok=True)

# Google Drive folder
drive_folder = "/content/drive/MyDrive/Urdu-OCR"
os.makedirs(drive_folder, exist_ok=True)

# Local labels.csv
with open("data/labels.csv", "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.DictWriter(f, fieldnames=["image", "text"])
    writer.writeheader()
    writer.writerows(labels)

# Google Drive labels.csv
with open(f"{drive_folder}/labels.csv", "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.DictWriter(f, fieldnames=["image", "text"])
    writer.writeheader()
    writer.writerows(labels)

print("✅ labels.csv created successfully!")
print(f"Total Labels: {len(labels)}")
print("Local Path : data/labels.csv")
print(f"Drive Path : {drive_folder}/labels.csv")
# Out:
# ✅ labels.csv created successfully!
# Total Labels: 100
# Local Path : data/labels.csv
# Drive Path : /content/drive/MyDrive/Urdu-OCR/labels.csv
